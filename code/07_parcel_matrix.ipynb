# %% [markdown]
# # IMPORTANT
# ## This notebook is not complete for the purposes of the final project submission. Will be completed over the summer.
# # Pawnee National Grassland Land Swap
# ## Compositing ecological, economic, contiguous, connectivity metrics into a parcel partrix
# - **Objective:** For this notebook,the values calculated or pull in previous notebooks are pulled into one function to generate a parcel matrix where parcels owned by "USA" are coded 0, and by "Colorado state of" are coded 1. The matrix will consider the total value from the metrics to identify best swaps.
#     - values include connectivity, contiguousness, ecological, and economic. Parcel size is also considered as a metric (acreage).
# - **Objective goals:**
#
# - **Author:** Kayleigh Ward
# - **Author:** Nate Hofford
# - **Author:** Max Warnock
# - **Code review and/or edits:** Kayleigh Ward
# - **Date:** April 9, 2026
# - **Last date of revision:** April 28, 2026
#
# ---
# ### 🛠️ Prerequisites & Setup
# * **Libraries:**
# * **Environment:**
# * **Data Sources:**
# * **Related Notebooks:**
# * **Notes:**
#
# ### 🏗️ Methodology
# 1.
# 2.
# 3.
# 4.
# 5.
# ---
# ### Reproducibility Notes
#
# ---
# ### ⚡ Troubleshooting/Notes
# *
#
# ---

# %% [markdown]
# # Libraries

# %% [markdown]
# # Primary Directory

# %%
### set up root file path
# Walk up from the current directory to find the repo root (contains .git)
_cwd = pathlib.Path(os.getcwd()).resolve()
repo_root = next(
    (p for p in [_cwd] + list(_cwd.parents) if (p / '.git').exists()),
    _cwd
)
os.chdir(repo_root)

data_dir = os.path.join(repo_root, 'data')
os.makedirs(data_dir, exist_ok=True)

print(f'Repo root: {repo_root}')

# %% [markdown]
# # Secondary Directories
