# %% [markdown]
# # IMPORTANT
# ## This notebook is not complete for the purposes of the final project submission. Will be completed over the summer.
# # Pawnee National Grassland Land Swap
# ## Parcel Connectivity Extraction - Western Pawnee Grasslands
# - **Objective:**
#
# For this notebook, the connectivity value for each parcel within the Pawnee National Grassland boundary. Values will be generated for each parcel, and in the `parcel_matrix` notebook these values will be appended to identify best land swaps.
#
# - **Objective goals:**
#
# - **Author:** Kayleigh Ward
# - **Code review and/or edits:**
# - **Date:** April 9, 2026
# - **Last date of revision:** April 28, 2026
#
# ---
# ### 🛠️ Prerequisites & Setup
# * **Libraries:**
# * **Environment:**
# * **Data Sources:**
# * **Related Notebooks:**
# * **Notes:**
#
# ### 🏗️ Methodology
# 1.
# 2.
# 3.
# 4.
# 5.
# ---
# ### Reproducibility Notes
#
# ---
# ### ⚡ Troubleshooting/Notes
# *
#
# ---

# %% [markdown]
# # Libraries

# %% [markdown]
# # Primary Directory

# %%
### set up root file path
# Walk up from the current directory to find the repo root (contains .git)
_cwd = pathlib.Path(os.getcwd()).resolve()
repo_root = next(
    (p for p in [_cwd] + list(_cwd.parents) if (p / '.git').exists()),
    _cwd
)
os.chdir(repo_root)

data_dir = os.path.join(repo_root, 'data')
os.makedirs(data_dir, exist_ok=True)

print(f'Repo root: {repo_root}')

# %% [markdown]
# # Secondary Directories
